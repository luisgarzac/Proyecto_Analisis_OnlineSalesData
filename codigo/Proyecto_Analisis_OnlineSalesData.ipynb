# %% [markdown]
# # **Proyecto Online Sales Data**

# %% [markdown]
# Fuente: https://www.kaggle.com/datasets/samruddhi4040/online-sales-data
#
# Elaborado por: Ing. Luis Garza

# %%
import pandas as pd

# Leer los archivos CSV
df_details = pd.read_csv("Details.csv")
df_orders = pd.read_csv("Orders.csv")

# Unir los DataFrames en base a la columna "Order ID"
df_merged = pd.merge(df_details, df_orders, on="Order ID")

# %%
df_merged.head(30)
# Out:
#    Order ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0   B-25681    1096     658         7  Electronics  Electronic Games
# 1   B-25681    1625     -77         3  Electronics            Phones
# 2   B-25681     523     204         7     Clothing          Trousers
# 3   B-25681      44      -3         1     Clothing             Saree
# 4   B-25681     243     -14         2    Furniture            Chairs
# 5   B-25681      68     -27         3  Electronics       Accessories
# 6   B-26055    5729      64        14    Furniture            Chairs
# 7   B-26055     671     114         9  Electronics            Phones
# 8   B-26055     443      11         1     Clothing             Saree
# 9   B-26055      57       7         2     Clothing             Shirt
# 10  B-26055     227      48         5     Clothing             Stole
# 11  B-26055     213       4        14     Clothing             Shirt
# 12  B-26055      94      27         2     Clothing           T-shirt
# 13  B-26055    1250     -12         2  Electronics          Printers
# 14  B-26055    1218    -420         8    Furniture         Bookcases
# 15  B-25955    2927     146         8    Furniture         Bookcases
# 16  B-25955      39       2         2     Clothing             Saree
# 17  B-25955      54      14         3     Clothing           T-shirt
# 18  B-25955     294      62         9     Clothing           T-shirt
# 19  B-25955     110      20         5     Clothing             Stole
# 20  B-25955     200      13         5  Electronics            Phones
# 21  B-25955      45       8         4     Clothing             Skirt
# 22  B-25955     954      95         3  Electronics          Printers
# 23  B-25955    1716     309         7  Electronics       Accessories
# 24  B-26093    2847     712         8  Electronics          Printers
# 25  B-26093     852      51         5    Furniture         Bookcases
# 26  B-26093     148      25         3     Clothing             Saree
# 27  B-26093      81     -41         5     Clothing          Leggings
# 28  B-26093      49       5         4     Clothing       Hankerchief
# 29  B-26093      33      -1         1     Clothing             Saree
#
#     PaymentMode  Order Date CustomerName           State     City
# 0           COD  04-06-2018       Bhawna  Madhya Pradesh   Indore
# 1           EMI  04-06-2018       Bhawna  Madhya Pradesh   Indore
# 2           COD  04-06-2018       Bhawna  Madhya Pradesh   Indore
# 3    Debit Card  04-06-2018       Bhawna  Madhya Pradesh   Indore
# 4           COD  04-06-2018       Bhawna  Madhya Pradesh   Indore
# 5           UPI  04-06-2018       Bhawna  Madhya Pradesh   Indore
# 6           EMI  10-03-2018    Harivansh   Uttar Pradesh  Mathura
# 7   Credit Card  10-03-2018    Harivansh   Uttar Pradesh  Mathura
# 8           COD  10-03-2018    Harivansh   Uttar Pradesh  Mathura
# 9           UPI  10-03-2018    Harivansh   Uttar Pradesh  Mathura
# 10          COD  10-03-2018    Harivansh   Uttar Pradesh  Mathura
# 11          COD  10-03-2018    Harivansh   Uttar Pradesh  Mathura
# 12          COD  10-03-2018    Harivansh   Uttar Pradesh  Mathura
# 13          EMI  10-03-2018    Harivansh   Uttar Pradesh  Mathura
# 14          COD  10-03-2018    Harivansh   Uttar Pradesh  Mathura
# 15          EMI  16-01-2018        Shiva     Maharashtra     Pune
# 16   Debit Card  16-01-2018        Shiva     Maharashtra     Pune
# 17          UPI  16-01-2018        Shiva     Maharashtra     Pune
# 18          EMI  16-01-2018        Shiva     Maharashtra     Pune
# 19   Debit Card  16-01-2018        Shiva     Maharashtra     Pune
# 20          COD  16-01-2018        Shiva     Maharashtra     Pune
# 21          EMI  16-01-2018        Shiva     Maharashtra     Pune
# 22          UPI  16-01-2018        Shiva     Maharashtra     Pune
# 23          COD  16-01-2018        Shiva     Maharashtra     Pune
# 24  Credit Card  27-03-2018       Sarita     Maharashtra     Pune
# 25  Credit Card  27-03-2018       Sarita     Maharashtra     Pune
# 26   Debit Card  27-03-2018       Sarita     Maharashtra     Pune
# 27          EMI  27-03-2018       Sarita     Maharashtra     Pune
# 28          COD  27-03-2018       Sarita     Maharashtra     Pune
# 29  Credit Card  27-03-2018       Sarita     Maharashtra     Pune

# %%
# Ordenar de menor a mayor la columna "Order ID"
df_sorted = df_merged.sort_values(by="Order ID")

# %%
df_sorted.head(30)
# Out:
#      Order ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 1238  B-25601       8      -2         3     Clothing       Hankerchief
# 1235  B-25601      80     -56         4  Electronics  Electronic Games
# 1236  B-25601      66     -12         5     Clothing             Stole
# 1237  B-25601    1275    1148         7    Furniture         Bookcases
# 35    B-25602     119      -5         8     Clothing             Saree
# 34    B-25602     168    -111         2  Electronics            Phones
# 33    B-25602     424    -272         5  Electronics            Phones
# 32    B-25602     561     212         3     Clothing             Saree
# 31    B-25602    2617    1151         4  Electronics            Phones
# 534   B-25603     107      36         6     Clothing             Stole
# 540   B-25603    1355     -60         5     Clothing          Trousers
# 535   B-25603     116      16         4     Clothing             Stole
# 536   B-25603     180       5         3     Clothing          Trousers
# 539   B-25603      24     -30         1    Furniture            Chairs
# 538   B-25603      38      18         1     Clothing             Kurti
# 533   B-25603      12       1         2     Clothing       Hankerchief
# 537   B-25603     193    -166         3     Clothing             Saree
# 1178  B-25604      65      17         2     Clothing           T-shirt
# 1179  B-25604     157       5         9     Clothing             Saree
# 1429  B-25605      75       0         7     Clothing             Saree
# 1329  B-25606      87       4         2     Clothing             Shirt
# 544   B-25607      50     -15         4     Clothing          Leggings
# 264   B-25608     257      23         5     Clothing       Hankerchief
# 263   B-25608     476       0         3    Furniture            Chairs
# 265   B-25608     856     385         6  Electronics          Printers
# 262   B-25608    1364    1864         5    Furniture            Tables
# 709   B-25609     485      29         4  Electronics  Electronic Games
# 710   B-25609     249      -5         4     Clothing             Saree
# 995   B-25610     781     594         6  Electronics          Printers
# 996   B-25610    1076     -38         4  Electronics          Printers
#
#       PaymentMode  Order Date CustomerName              State       City
# 1238  Credit Card  01-04-2018       Bharat            Gujarat  Ahmedabad
# 1235          UPI  01-04-2018       Bharat            Gujarat  Ahmedabad
# 1236          UPI  01-04-2018       Bharat            Gujarat  Ahmedabad
# 1237          EMI  01-04-2018       Bharat            Gujarat  Ahmedabad
# 35    Credit Card  01-04-2018       Vrinda        Maharashtra       Pune
# 34            EMI  01-04-2018       Vrinda        Maharashtra       Pune
# 33            COD  01-04-2018       Vrinda        Maharashtra       Pune
# 32            COD  01-04-2018       Vrinda        Maharashtra       Pune
# 31    Credit Card  01-04-2018       Vrinda        Maharashtra       Pune
# 534           COD  03-04-2018        Jahan     Madhya Pradesh     Bhopal
# 540           COD  03-04-2018        Jahan     Madhya Pradesh     Bhopal
# 535           COD  03-04-2018        Jahan     Madhya Pradesh     Bhopal
# 536    Debit Card  03-04-2018        Jahan     Madhya Pradesh     Bhopal
# 539           COD  03-04-2018        Jahan     Madhya Pradesh     Bhopal
# 538           COD  03-04-2018        Jahan     Madhya Pradesh     Bhopal
# 533           COD  03-04-2018        Jahan     Madhya Pradesh     Bhopal
# 537           EMI  03-04-2018        Jahan     Madhya Pradesh     Bhopal
# 1178          UPI  03-04-2018       Divsha          Rajasthan     Jaipur
# 1179          UPI  03-04-2018       Divsha          Rajasthan     Jaipur
# 1429          EMI  05-04-2018      Kasheen        West Bengal    Kolkata
# 1329          COD  06-04-2018        Hazel          Karnataka  Bangalore
# 544           COD  06-04-2018     Sonakshi  Jammu and Kashmir    Kashmir
# 264           COD  08-04-2018      Aarushi         Tamil Nadu    Chennai
# 263           COD  08-04-2018      Aarushi         Tamil Nadu    Chennai
# 265           COD  08-04-2018      Aarushi         Tamil Nadu    Chennai
# 262   Credit Card  08-04-2018      Aarushi         Tamil Nadu    Chennai
# 709           COD  09-04-2018       Jitesh      Uttar Pradesh    Lucknow
# 710           COD  09-04-2018       Jitesh      Uttar Pradesh    Lucknow
# 995    Debit Card  09-04-2018       Yogesh              Bihar      Patna
# 996           COD  09-04-2018       Yogesh              Bihar      Patna

# %%
# Guardar los datos actualizados en un nuevo archivo CSV
df_sorted.to_csv("onlinesales_sorted.csv", index=False)

# %%
df_online_sales = pd.read_csv("onlinesales_sorted.csv")

# %%
df_online_sales
# Out:
#      Order ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0     B-25601       8      -2         3     Clothing       Hankerchief
# 1     B-25601      80     -56         4  Electronics  Electronic Games
# 2     B-25601      66     -12         5     Clothing             Stole
# 3     B-25601    1275    1148         7    Furniture         Bookcases
# 4     B-25602     119      -5         8     Clothing             Saree
# ...       ...     ...     ...       ...          ...               ...
# 1495  B-26099     207      37         4     Clothing       Hankerchief
# 1496  B-26099    2366     552         5     Clothing          Trousers
# 1497  B-26100     828     230         2    Furniture            Chairs
# 1498  B-26100      72      16         2     Clothing             Shirt
# 1499  B-26100      34      10         2     Clothing           T-shirt
#
#       PaymentMode  Order Date CustomerName           State       City
# 0     Credit Card  01-04-2018       Bharat         Gujarat  Ahmedabad
# 1             UPI  01-04-2018       Bharat         Gujarat  Ahmedabad
# 2             UPI  01-04-2018       Bharat         Gujarat  Ahmedabad
# 3             EMI  01-04-2018       Bharat         Gujarat  Ahmedabad
# 4     Credit Card  01-04-2018       Vrinda     Maharashtra       Pune
# ...           ...         ...          ...             ...        ...
# 1495          COD  30-03-2018       Bhishm     Maharashtra     Mumbai
# 1496          UPI  30-03-2018       Bhishm     Maharashtra     Mumbai
# 1497          COD  31-03-2018       Hitika  Madhya Pradesh     Indore
# 1498          COD  31-03-2018       Hitika  Madhya Pradesh     Indore
# 1499   Debit Card  31-03-2018       Hitika  Madhya Pradesh     Indore
#
# [1500 rows x 11 columns]

# %% [markdown]
# ### Análisis exploratorio de datos

# %%
# Información general del DataFrame
print("\nInformación general del DataFrame:")
print(df_online_sales.info())
# Out:
# Información general del DataFrame:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order ID      1500 non-null   object
#  1   Amount        1500 non-null   int64
#  2   Profit        1500 non-null   int64
#  3   Quantity      1500 non-null   int64
#  4   Category      1500 non-null   object
#  5   Sub-Category  1500 non-null   object
#  6   PaymentMode   1500 non-null   object
#  7   Order Date    1500 non-null   object
#  8   CustomerName  1500 non-null   object
#  9   State         1500 non-null   object
#  10  City          1500 non-null   object
# dtypes: int64(3), object(8)
# memory usage: 129.0+ KB
# None

# %%
# Resumen estadístico del DataFrame
print("\nResumen estadístico del DataFrame:")
print(df_online_sales.describe())
# Out:
# Resumen estadístico del DataFrame:
#             Amount      Profit     Quantity
# count  1500.000000  1500.00000  1500.000000
# mean    291.847333    24.64200     3.743333
# std     461.924620   168.55881     2.184942
# min       4.000000 -1981.00000     1.000000
# 25%      47.750000   -12.00000     2.000000
# 50%     122.000000     8.00000     3.000000
# 75%     326.250000    38.00000     5.000000
# max    5729.000000  1864.00000    14.000000

# %%
# Análisis de variables categóricas
print("\nAnálisis de variables categóricas:")
print("Categoría:")
print(df_online_sales['Category'].value_counts())
print("\nSub-Categoría:")
print(df_online_sales['Sub-Category'].value_counts())
print("\nModo de Pago:")
print(df_online_sales['PaymentMode'].value_counts())
print("\nEstado:")
print(df_online_sales['State'].value_counts())
print("\nCiudad:")
print(df_online_sales['City'].value_counts())
# Out:
# Análisis de variables categóricas:
# Categoría:
# Category
# Clothing       949
# Electronics    308
# Furniture      243
# Name: count, dtype: int64
#
# Sub-Categoría:
# Sub-Category
# Saree               211
# Hankerchief         197
# Stole               192
# Phones               83
# Bookcases            79
# Electronic Games     79
# T-shirt              77
# Printers             74
# Chairs               74
# Furnishings          73
# Accessories          72
# Shirt                69
# Skirt                64
# Leggings             53
# Kurti                47
# Trousers             39
# Tables               17
# Name: count, dtype: int64
#
# Modo de Pago:
# PaymentMode
# COD            684
# UPI            331
# Debit Card     202
# Credit Card    163
# EMI            120
# Name: count, dtype: int64
#
# Estado:
# State
# Madhya Pradesh       314
# Maharashtra          299
# Gujarat               87
# Uttar Pradesh         87
# Delhi                 76
# Rajasthan             74
# West Bengal           63
# Bihar                 62
# Punjab                60
# Karnataka             50
# Jammu and Kashmir     49
# Kerala                45
# Nagaland              45
# Goa                   43
# Andhra Pradesh        42
# Himachal Pradesh      29
# Haryana               26
# Tamil Nadu            25
# Sikkim                24
# Name: count, dtype: int64
#
# Ciudad:
# City
# Indore                248
# Mumbai                201
# Pune                   98
# Delhi                  76
# Chandigarh             71
# Bhopal                 66
# Kolkata                63
# Patna                  62
# Ahmedabad              62
# Bangalore              50
# Kashmir                49
# Thiruvananthapuram     45
# Kohima                 45
# Jaipur                 44
# Goa                    43
# Hyderabad              42
# Lucknow                38
# Mathura                37
# Udaipur                30
# Simla                  29
# Chennai                25
# Surat                  25
# Gangtok                24
# Amritsar               15
# Prayagraj              12
# Name: count, dtype: int64

# %%
# Número de estados
num_states = df_online_sales['State'].nunique()
print("Número de estados:", num_states)

# Número de ciudades
num_cities = df_online_sales['City'].nunique()
print("Número de ciudades:", num_cities)
# Out:
# Número de estados: 19
# Número de ciudades: 25

# %%
# Visualización de datos
# Visualización de la distribución de las categorías
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
df_online_sales['Category'].value_counts().plot(kind='bar')
plt.title('Distribución de Categorías')
plt.xlabel('Categoría')
plt.ylabel('Cantidad')
plt.show()

# %%
# Visualización de la distribución de los modos de pago
plt.figure(figsize=(10, 6))
df_online_sales['PaymentMode'].value_counts().plot(kind='bar')
plt.title('Distribución de Modos de Pago')
plt.xlabel('Modo de Pago')
plt.ylabel('Cantidad')
plt.show()

# %%
# Visualización de la distribución de las ventas por estado
plt.figure(figsize=(12, 6))
df_online_sales['State'].value_counts().plot(kind='bar')
plt.title('Distribución de Ventas por Estado')
plt.xlabel('Estado')
plt.ylabel('Cantidad de Ventas')
plt.xticks(rotation=90)
plt.show()

# %%
import matplotlib.pyplot as plt

# Variables numéricas relevantes para el análisis
numeric_variables = ['Amount', 'Profit', 'Quantity']

# Calculando medidas estadísticas básicas
statistics = df_online_sales[numeric_variables].describe()
print("Medidas estadísticas básicas:")
print(statistics)

# Calcular el rango intercuartílico (IQR)
Q1 = df_online_sales[numeric_variables].quantile(0.25)
Q3 = df_online_sales[numeric_variables].quantile(0.75)
IQR = Q3 - Q1

# Calcular límites superior e inferior para detección de outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Visualización de boxplots para detectar outliers
plt.figure(figsize=(12, 6))
for i, var in enumerate(numeric_variables):
    plt.subplot(1, len(numeric_variables), i + 1)
    plt.boxplot(df_online_sales[var])
    plt.title(var)
plt.tight_layout()
plt.show()

# Identificar y contar outliers para cada variable numérica
outliers = ((df_online_sales[numeric_variables] < lower_bound) | (df_online_sales[numeric_variables] > upper_bound)).sum()
print("\nNúmero de outliers por variable:")
print(outliers)
# Out:
# Medidas estadísticas básicas:
#             Amount      Profit     Quantity
# count  1500.000000  1500.00000  1500.000000
# mean    291.847333    24.64200     3.743333
# std     461.924620   168.55881     2.184942
# min       4.000000 -1981.00000     1.000000
# 25%      47.750000   -12.00000     2.000000
# 50%     122.000000     8.00000     3.000000
# 75%     326.250000    38.00000     5.000000
# max    5729.000000  1864.00000    14.000000
# Número de outliers por variable:
# Amount      152
# Profit      275
# Quantity     23
# dtype: int64

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Análisis de tendencias temporales
# Convertir la columna de fecha a formato datetime
df_online_sales['Order Date'] = pd.to_datetime(df_online_sales['Order Date'], format='%d-%m-%Y')
# Crear una nueva columna con el mes de cada orden
df_online_sales['Order Month'] = df_online_sales['Order Date'].dt.to_period('M')

# Agrupar los datos por mes y sumar las ventas para cada mes
monthly_sales = df_online_sales.groupby('Order Month')['Amount'].sum()

# Graficar las tendencias temporales
plt.figure(figsize=(10, 6))
monthly_sales.plot(marker='o', color='b', linestyle='-')
plt.title('Tendencias Temporales de Ventas')
plt.xlabel('Mes')
plt.ylabel('Ventas Totales')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Exploración de relaciones**

# %%
import matplotlib.pyplot as plt

# Histograma de la variable 'Amount'
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.hist(df_online_sales['Amount'], bins=20, color='skyblue', edgecolor='black')
plt.title('Histograma de Amount')
plt.xlabel('Amount')
plt.ylabel('Frecuencia')

# Gráfico de dispersión de 'Amount' vs. índice
plt.subplot(1, 2, 2)
plt.scatter(df_online_sales.index, df_online_sales['Amount'], color='salmon', alpha=0.7)
plt.title('Gráfico de dispersión de Amount vs. Índice')
plt.xlabel('Índice')
plt.ylabel('Amount')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Histograma de la variable 'Profit'
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.hist(df_online_sales['Profit'], bins=20, color='lightgreen', edgecolor='black')
plt.title('Histograma de Profit')
plt.xlabel('Profit')
plt.ylabel('Frecuencia')

# Gráfico de dispersión de 'Profit' vs. índice
plt.subplot(1, 2, 2)
plt.scatter(df_online_sales.index, df_online_sales['Profit'], color='orange', alpha=0.7)
plt.title('Gráfico de dispersión de Profit vs. Índice')
plt.xlabel('Índice')
plt.ylabel('Profit')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Histograma de la variable 'Quantity'
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.hist(df_online_sales['Quantity'], bins=20, color='lightblue', edgecolor='black')
plt.title('Histograma de Quantity')
plt.xlabel('Quantity')
plt.ylabel('Frecuencia')

# Gráfico de dispersión de 'Quantity' vs. índice
plt.subplot(1, 2, 2)
plt.scatter(df_online_sales.index, df_online_sales['Quantity'], color='purple', alpha=0.7)
plt.title('Gráfico de dispersión de Quantity vs. Índice')
plt.xlabel('Índice')
plt.ylabel('Quantity')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Analisis de datos**

# %%
# Rentabilidad por categoría de producto
category_profit = df_online_sales.groupby('Category')['Profit'].sum()  # Agrupamos por categoría y sumamos las ganancias
category_profit.plot(kind='bar', color='skyblue')  # Creamos un gráfico de barras para la rentabilidad por categoría
plt.title('Rentabilidad por Categoría de Producto')  # Agregamos un título al gráfico
plt.xlabel('Categoría')  # Etiqueta del eje x
plt.ylabel('Rentabilidad Total')  # Etiqueta del eje y
plt.xticks(rotation=45, ha='right')  # Rotamos las etiquetas del eje x para mejor visualización
plt.show()  # Mostramos el gráfico

# %%
# Rentabilidad por subcategoría
subcategory_profit = df_online_sales.groupby('Sub-Category')['Profit'].sum()  # Agrupamos por subcategoría y sumamos las ganancias
subcategory_profit.plot(kind='bar', color='lightgreen')  # Creamos un gráfico de barras para la rentabilidad por subcategoría
plt.title('Rentabilidad por Subcategoría de Producto')  # Agregamos un título al gráfico
plt.xlabel('Subcategoría')  # Etiqueta del eje x
plt.ylabel('Rentabilidad Total')  # Etiqueta del eje y
plt.xticks(rotation=45, ha='right')  # Rotamos las etiquetas del eje x para mejor visualización
plt.show()  # Mostramos el gráfico

# %%
# Rentabilidad por método de pago
payment_profit = df_online_sales.groupby('PaymentMode')['Profit'].sum()  # Agrupamos por método de pago y sumamos las ganancias
payment_profit.plot(kind='bar', color='salmon')  # Creamos un gráfico de barras para la rentabilidad por método de pago
plt.title('Rentabilidad por Método de Pago')  # Agregamos un título al gráfico
plt.xlabel('Método de Pago')  # Etiqueta del eje x
plt.ylabel('Rentabilidad Total')  # Etiqueta del eje y
plt.xticks(rotation=45, ha='right')  # Rotamos las etiquetas del eje x para mejor visualización
plt.show()  # Mostramos el gráfico

# %%
# Segmentación de clientes por ciudad
customer_segmentation = df_online_sales.groupby('City')

# Analizar el comportamiento de compra de cada segmento
for city, data in customer_segmentation:
    print(f"Comportamiento de compra en {city}:")
    print("Número de compras:", data.shape[0])  # Número de compras realizadas en la ciudad
    print("Gasto promedio por compra:", data['Amount'].mean())  # Gasto promedio por compra en la ciudad
    print("Productos más comprados:")
    print(data['Sub-Category'].value_counts().head(3))  # Subcategorías más compradas en la ciudad
    print()
# Out:
# Comportamiento de compra en Ahmedabad:
# Número de compras: 62
# Gasto promedio por compra: 234.56451612903226
# Productos más comprados:
# Sub-Category
# Saree          11
# Stole           9
# Hankerchief     7
# Name: count, dtype: int64
#
# Comportamiento de compra en Amritsar:
# Número de compras: 15
# Gasto promedio por compra: 300.46666666666664
# Productos más comprados:
# Sub-Category
# T-shirt             3
# Accessories         3
# Electronic Games    2
# Name: count, dtype: int64
#
# Comportamiento de compra en Bangalore:
# Número de compras: 50
# Gasto promedio por compra: 250.4
# Productos más comprados:
# Sub-Category
# Hankerchief    8
# Saree          8
# Shirt          7
# Name: count, dtype: int64
#
# Comportamiento de compra en Bhopal:
# Número de compras: 66
# Gasto promedio por compra: 360.3484848484849
# Productos más comprados:
# Sub-Category
# Hankerchief    10
# Saree          10
# Stole           6
# Name: count, dtype: int64
#
# Comportamiento de compra en Chandigarh:
# Número de compras: 71
# Gasto promedio por compra: 297.77464788732397
# Productos más comprados:
# Sub-Category
# Saree          13
# Stole           9
# Hankerchief     9
# Name: count, dtype: int64
#
# Comportamiento de compra en Chennai:
# Número de compras: 25
# Gasto promedio por compra: 251.04
# Productos más comprados:
# Sub-Category
# Hankerchief    6
# Saree          5
# Stole          3
# Name: count, dtype: int64
#
# Comportamiento de compra en Delhi:
# Número de compras: 76
# Gasto promedio por compra: 302.0657894736842
# Productos más comprados:
# Sub-Category
# Stole          14
# Saree           9
# Hankerchief     7
# Name: count, dtype: int64
#
# Comportamiento de compra en Gangtok:
# Número de compras: 24
# Gasto promedio por compra: 219.83333333333334
# Productos más comprados:
# Sub-Category
# Hankerchief    6
# Stole          5
# Phones         3
# Name: count, dtype: int64
#
# Comportamiento de compra en Goa:
# Número de compras: 43
# Gasto promedio por compra: 155.93023255813952
# Productos más comprados:
# Sub-Category
# Hankerchief    12
# Stole           8
# Leggings        4
# Name: count, dtype: int64
#
# Comportamiento de compra en Hyderabad:
# Número de compras: 42
# Gasto promedio por compra: 315.6190476190476
# Productos más comprados:
# Sub-Category
# Stole          10
# Hankerchief     8
# Printers        5
# Name: count, dtype: int64
#
# Comportamiento de compra en Indore:
# Número de compras: 248
# Gasto promedio por compra: 256.7741935483871
# Productos más comprados:
# Sub-Category
# Hankerchief    41
# Saree          29
# Stole          28
# Name: count, dtype: int64
#
# Comportamiento de compra en Jaipur:
# Número de compras: 44
# Gasto promedio por compra: 255.9318181818182
# Productos más comprados:
# Sub-Category
# Saree      9
# Chairs     5
# T-shirt    4
# Name: count, dtype: int64
#
# Comportamiento de compra en Kashmir:
# Número de compras: 49
# Gasto promedio por compra: 221.0
# Productos más comprados:
# Sub-Category
# Chairs         7
# Saree          5
# Hankerchief    5
# Name: count, dtype: int64
#
# Comportamiento de compra en Kohima:
# Número de compras: 45
# Gasto promedio por compra: 266.5111111111111
# Productos más comprados:
# Sub-Category
# Saree          8
# Hankerchief    6
# Stole          6
# Name: count, dtype: int64
#
# Comportamiento de compra en Kolkata:
# Número de compras: 63
# Gasto promedio por compra: 227.42857142857142
# Productos más comprados:
# Sub-Category
# Saree          12
# Stole          11
# Accessories     7
# Name: count, dtype: int64
#
# Comportamiento de compra en Lucknow:
# Número de compras: 38
# Gasto promedio por compra: 150.68421052631578
# Productos más comprados:
# Sub-Category
# Hankerchief    7
# Stole          5
# Saree          4
# Name: count, dtype: int64
#
# Comportamiento de compra en Mathura:
# Número de compras: 37
# Gasto promedio por compra: 776.9459459459459
# Productos más comprados:
# Sub-Category
# Stole    5
# Saree    4
# Shirt    4
# Name: count, dtype: int64
#
# Comportamiento de compra en Mumbai:
# Número de compras: 201
# Gasto promedio por compra: 292.9651741293532
# Productos más comprados:
# Sub-Category
# Saree          34
# Stole          29
# Hankerchief    21
# Name: count, dtype: int64
#
# Comportamiento de compra en Patna:
# Número de compras: 62
# Gasto promedio por compra: 216.40322580645162
# Productos más comprados:
# Sub-Category
# Stole          8
# Hankerchief    8
# Saree          7
# Name: count, dtype: int64
#
# Comportamiento de compra en Prayagraj:
# Número de compras: 12
# Gasto promedio por compra: 324.0833333333333
# Productos más comprados:
# Sub-Category
# Saree    3
# Skirt    3
# Shirt    1
# Name: count, dtype: int64
#
# Comportamiento de compra en Pune:
# Número de compras: 98
# Gasto promedio por compra: 445.0204081632653
# Productos más comprados:
# Sub-Category
# Saree          19
# Hankerchief    13
# Printers       10
# Name: count, dtype: int64
#
# Comportamiento de compra en Simla:
# Número de compras: 29
# Gasto promedio por compra: 298.82758620689657
# Productos más comprados:
# Sub-Category
# Stole               8
# Electronic Games    3
# Furnishings         3
# Name: count, dtype: int64
#
# Comportamiento de compra en Surat:
# Número de compras: 25
# Gasto promedio por compra: 273.12
# Productos más comprados:
# Sub-Category
# Hankerchief    5
# T-shirt        4
# Stole          3
# Name: count, dtype: int64
#
# Comportamiento de compra en Thiruvananthapuram:
# Número de compras: 45
# Gasto promedio por compra: 308.24444444444447
# Productos más comprados:
# Sub-Category
# Saree     11
# Stole      6
# Chairs     5
# Name: count, dtype: int64
#
# Comportamiento de compra en Udaipur:
# Número de compras: 30
# Gasto promedio por compra: 369.1
# Productos más comprados:
# Sub-Category
# T-shirt    4
# Stole      4
# Shirt      4
# Name: count, dtype: int64

# %%
# Generar grafico que  muestre ventas totales, rentabilidad total, ventas rea.izadas y clientes totales


# Calcular las métricas
total_sales = df_online_sales['Amount'].sum()
total_profit = df_online_sales['Profit'].sum()
total_customers = df_online_sales['CustomerName'].nunique()
total_orders = len(df_online_sales)

# Crear el tablero con subgráficos
fig, axes = plt.subplots(2, 2, figsize=(12, 8))

# Graficar las ventas totales
axes[0, 0].bar('Ventas Totales', total_sales, color='blue')
axes[0, 0].text('Ventas Totales', total_sales, str(total_sales), ha='center', va='bottom', fontsize=10)
axes[0, 0].set_ylabel('Cantidad')
axes[0, 0].set_title('Ventas Totales')

# Graficar la rentabilidad total
axes[0, 1].bar('Rentabilidad Total', total_profit, color='green')
axes[0, 1].text('Rentabilidad Total', total_profit, str(total_profit), ha='center', va='bottom', fontsize=10)
axes[0, 1].set_ylabel('Cantidad')
axes[0, 1].set_title('Rentabilidad Total')

# Graficar el número total de clientes
axes[1, 0].bar('Clientes Totales', total_customers, color='orange')
axes[1, 0].text('Clientes Totales', total_customers, str(total_customers), ha='center', va='bottom', fontsize=10)
axes[1, 0].set_ylabel('Cantidad')
axes[1, 0].set_title('Clientes Totales')

# Graficar el número total de ventas realizadas
axes[1, 1].bar('Ventas Realizadas', total_orders, color='red')
axes[1, 1].text('Ventas Realizadas', total_orders, str(total_orders), ha='center', va='bottom', fontsize=10)
axes[1, 1].set_ylabel('Cantidad')
axes[1, 1].set_title('Ventas Realizadas')

# Ajustar el espacio entre los subgráficos
plt.tight_layout()

# Mostrar el tablero
plt.show()

# %%
# Agrupar por ciudad y método de pago, contar el número de transacciones y encontrar el método de pago más común
city_payment_counts = df_online_sales.groupby(['City', 'PaymentMode']).size().reset_index(name='Count')
city_most_common_payment = city_payment_counts.loc[city_payment_counts.groupby('City')['Count'].idxmax()]

# Mostrar los resultados
print(city_most_common_payment)
# Out:
#                    City PaymentMode  Count
# 0             Ahmedabad         COD     26
# 5              Amritsar         COD      7
# 10            Bangalore         COD     21
# 15               Bhopal         COD     36
# 20           Chandigarh         COD     34
# 25              Chennai         COD     13
# 29                Delhi         COD     37
# 37              Gangtok         UPI     10
# 38                  Goa         COD     25
# 43            Hyderabad         COD     15
# 48               Indore         COD    111
# 53               Jaipur         COD     16
# 58              Kashmir         COD     23
# 63               Kohima         COD     17
# 68              Kolkata         COD     29
# 73              Lucknow         COD     25
# 78              Mathura         COD     16
# 83               Mumbai         COD    104
# 88                Patna         COD     23
# 93            Prayagraj         COD      4
# 98                 Pune         COD     41
# 103               Simla         COD     17
# 112               Surat         UPI      8
# 113  Thiruvananthapuram         COD     15
# 118             Udaipur         COD     16

# %%
# Filtrar el DataFrame para incluir solo transacciones con tarjeta de crédito
credit_card_transactions = df_online_sales[df_online_sales['PaymentMode'] == 'Credit Card']

# Contar el número de transacciones por ciudad
city_credit_card_counts = credit_card_transactions['City'].value_counts()

# Mostrar los resultados
print(city_credit_card_counts)
# Out:
# City
# Indore                26
# Pune                  15
# Mumbai                13
# Delhi                  8
# Hyderabad              8
# Thiruvananthapuram     8
# Bhopal                 8
# Bangalore              7
# Mathura                7
# Kashmir                7
# Kolkata                7
# Jaipur                 6
# Kohima                 6
# Chandigarh             5
# Ahmedabad              5
# Patna                  4
# Lucknow                4
# Goa                    4
# Simla                  4
# Surat                  4
# Chennai                4
# Prayagraj              1
# Udaipur                1
# Amritsar               1
# Name: count, dtype: int64

# %%
# Filtrar el DataFrame para incluir solo transacciones de la categoría "Clothing"
clothing_transactions = df_online_sales[df_online_sales['Category'] == 'Clothing']

# Contar el número de veces que se utilizó cada método de pago
payment_mode_counts = clothing_transactions['PaymentMode'].value_counts()

# Mostrar los resultados
print(payment_mode_counts)
# Out:
# PaymentMode
# COD            446
# UPI            221
# Debit Card     128
# Credit Card     89
# EMI             65
# Name: count, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Asegúrate de tener las fechas en formato de fecha, si no están, conviértelas usando pd.to_datetime()

# Agrupar por mes y categoría y contar las ventas
sales_by_month_category = df_online_sales.groupby([df_online_sales['Order Date'].dt.month, 'Category']).size().unstack()

# Gráfico de líneas para cada categoría
sales_by_month_category.plot(kind='line', marker='o', figsize=(10, 6))
plt.title('Cantidad de compras por categoría y mes')
plt.xlabel('Mes')
plt.ylabel('Cantidad de compras')
plt.xticks(range(1, 13), ['Ene', 'Feb', 'Mar', 'Abr', 'May', 'Jun', 'Jul', 'Ago', 'Sep', 'Oct', 'Nov', 'Dic'])
plt.legend(title='Categoría')
plt.grid(True)
plt.show()

# %%
df_online_sales.head(10)
# Out:
#   Order ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0  B-25601       8      -2         3     Clothing       Hankerchief
# 1  B-25601      80     -56         4  Electronics  Electronic Games
# 2  B-25601      66     -12         5     Clothing             Stole
# 3  B-25601    1275    1148         7    Furniture         Bookcases
# 4  B-25602     119      -5         8     Clothing             Saree
# 5  B-25602     168    -111         2  Electronics            Phones
# 6  B-25602     424    -272         5  Electronics            Phones
# 7  B-25602     561     212         3     Clothing             Saree
# 8  B-25602    2617    1151         4  Electronics            Phones
# 9  B-25603     107      36         6     Clothing             Stole
#
#    PaymentMode Order Date CustomerName           State       City Order Month
# 0  Credit Card 2018-04-01       Bharat         Gujarat  Ahmedabad     2018-04
# 1          UPI 2018-04-01       Bharat         Gujarat  Ahmedabad     2018-04
# 2          UPI 2018-04-01       Bharat         Gujarat  Ahmedabad     2018-04
# 3          EMI 2018-04-01       Bharat         Gujarat  Ahmedabad     2018-04
# 4  Credit Card 2018-04-01       Vrinda     Maharashtra       Pune     2018-04
# 5          EMI 2018-04-01       Vrinda     Maharashtra       Pune     2018-04
# 6          COD 2018-04-01       Vrinda     Maharashtra       Pune     2018-04
# 7          COD 2018-04-01       Vrinda     Maharashtra       Pune     2018-04
# 8  Credit Card 2018-04-01       Vrinda     Maharashtra       Pune     2018-04
# 9          COD 2018-04-03        Jahan  Madhya Pradesh     Bhopal     2018-04
